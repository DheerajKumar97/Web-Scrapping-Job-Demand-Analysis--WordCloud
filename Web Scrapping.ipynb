# %% [markdown]
# ### **Connect with me in** :- https://www.linkedin.com/in/dheerajkumar1997/

# %% [markdown]
# # Web Scrapping

# %%
import urllib.request
import requests
from bs4 import BeautifulSoup
import re
import ast
url = "https://www.cnbc.com/2019/01/08/the-25-most-in-demand-technical-skills-of-2019-according-to-linkedin-.html"

# %%
response = requests.get(url)
content = str(response.content)
p = content.find("phone")
content=content[p:]

# %%
content_list = content.split("Machine learning ")

# %%
content_list = content_list + f

# %%
features = []
for feature in content_list:
    feature = feature.replace("(\\\)"," ");
    feature = feature.replace("\\"," ");
    feature = feature.replace("typename"," ");
    feature = feature.replace("https","");
    feature = feature.replace("u002F"," ");
    feature = feature.replace("tagName"," ");
    feature = feature.replace("null","");
    feature = feature.replace("image","");
    features.append(feature)

# %%
features = features[0].split("job")
features = features+f

# %%
final_data=[]
for data in features:
    if ":" not in data:
        continue
    final_data.append(data)
    #print(data)
#     if 'title"' not in data: continue
#     if "job" in data: continue
#     if "Length" in data: continue
#     if "_length" in data: continue

final_data = final_data+f+content_list

# %%
import matplotlib.pyplot as plt
from wordcloud import WordCloud
wordcloud = WordCloud(width = 1000, height = 500).generate(" ".join(final_data))
wordcloud
plt.figure(figsize=(15,8))
plt.imshow(wordcloud)
plt.axis("off")
#plt.savefig("your_file_name"+".png", bbox_inches='tight')
plt.show()
plt.close()

# %%
import urllib.request
import requests
from bs4 import BeautifulSoup
import re
import ast
url1 = "https://www.naukri.com/top-skill-jobs"

# %%
response = requests.get(url)
words = str(response.content)
p = words.find("skills")
words=words[p:]

# %%
words_list = words.split("jobs")
words_list = words.split("Computer Science Jobs")

# %%
word_feature = []
for feature in words_list:
    feature = feature.replace("(\\\)"," ");
    feature = feature.replace("/"," ");
    feature = feature.replace("\\\\"," ");
    feature = feature.replace("(\\\)"," ");
    feature = feature.replace("(\\\';\\\')"," ");
    feature = feature.replace("(\\n )"," ");
    feature = feature.replace("false"," ");
    feature = feature.replace("id"," ");
    feature = feature.replace("children"," ");
    feature = feature.replace("cnbc"," ");
    feature = feature.replace("module"," ");
    feature = feature.replace("false"," ");
    feature = feature.replace("section"," ");
    feature = feature.replace("attributes"," ");
    word_feature.append(feature)

# %%
subs ="Software"
res = [i for i in word_feature if subs in i]

# %%
res = res[0].split("job")
res = res+f

# %%
import matplotlib.pyplot as plt
from wordcloud import WordCloud
wordcloud = WordCloud(width = 1000, height = 500).generate(" ".join(features))
wordcloud
plt.figure(figsize=(15,8))
plt.imshow(wordcloud)
plt.axis("off")
#plt.savefig("your_file_name"+".png", bbox_inches='tight')
plt.show()
plt.close()

# %%
f = open("jobs.txt")
f=f.read()

# %%
f=f.split()

# %%
import matplotlib.pyplot as plt
from wordcloud import WordCloud
wordcloud = WordCloud(width = 1000, height = 500).generate(" ".join(f))
wordcloud
plt.figure(figsize=(15,8))
plt.imshow(wordcloud)
plt.axis("off")
#plt.savefig("your_file_name"+".png", bbox_inches='tight')
plt.show()
plt.close()

# %% [markdown]
# .

# %% [markdown]
# ### **Connect with me in** :- https://www.linkedin.com/in/dheerajkumar1997/
